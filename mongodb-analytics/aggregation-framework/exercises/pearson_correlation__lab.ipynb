# %%
# %%capture
import sys
# !{sys.executable} -m pip install numpy pandas seaborn scipy
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib as plt
import zlib
import json
from pymongo import MongoClient
from scipy.stats import pearsonr
# %matplotlib inline
sns.set(color_codes=True)
sns.set(color_codes=True)

# %%
course_cluster_uri = "mongodb://agg-student:agg-password@cluster0-shard-00-00-jxeqq.mongodb.net:27017,cluster0-shard-00-01-jxeqq.mongodb.net:27017,cluster0-shard-00-02-jxeqq.mongodb.net:27017/test?ssl=true&replicaSet=Cluster0-shard-0&authSource=admin"
course_client = MongoClient(course_cluster_uri)

# %%
db = course_client['100YWeatherSmall']
weather = db['data']

# %%
pipeline = [
    {
        "$match": {
            "airTemperature.value": { "$gte": -100, "$lte": 100 },
            "pressure.value": { "$lt": 9000}
        }
    },
    {
        "$project": {
            "_id": 0,
            "temperature": "$airTemperature.value",
            "pressure": "$pressure.value"
        }
    }
]

# %%
df = pd.DataFrame.from_dict(list(weather.aggregate(pipeline)))

# %%
df.head()
# Out:
#    temperature  pressure
# 0        -85.0    1007.3
# 1        -81.0    1014.5
# 2        -80.1    1014.7
# 3        -80.0    1023.0
# 4        -80.0    1017.6

# %% [markdown]
# # Gay-Lussac's Law
#
# From [Wikipedia](https://en.wikipedia.org/wiki/Gay-Lussac%27s_law#Pressure-temperature_law)
# > The pressure of a gas of fixed mass and fixed volume,is directly proportional to the gas's absolute temperature.
#
# Does this hold true for Earth's complex atmosphere?

# %%
sns.jointplot(x="pressure", y="temperature", data=df, kind='reg',
                  joint_kws={'line_kws':{'color':'red'}, 'scatter_kws': { 'alpha': 0.5, 's': 20}}, height=8 )

# %% [markdown]
# ## Calculate within MongoDB
#
# Calculate the Pearson Correlation between `airTemperature.value` and `pressure.value` in MongoDB.

# %%
# don't change these
X = '$airTemperature.value'
Y = '$pressure.value'

# %%
# match stage is provided for you
# we have selected these ranges because errors or missing information from the sensors is represented by values
# out of these bounds!
match_stage = {
    "$match": {
        "airTemperature.value": { "$gte": -100, "$lte": 100 },
        "pressure.value": { "$lt": 9000}
    }
}

# %%
# todo: assign proper values
elems = {"$sum": 1}
sum_x = {"$sum": X}
sum_y = {"$sum": Y}
sum_x2 = {"$sum": {"$multiply": [X, X]}}
sum_y2 = {"$sum": {"$multiply": [Y, Y]}}
sum_xy = {"$sum": {"$multiply": [X, Y]}}

all_sums = {
    "$group": {
        "_id": None,
        "elems": elems,
        "sum_x": sum_x,
        "sum_y": sum_y,
        "sum_x2": sum_x2,
        "sum_y2": sum_y2,
        "sum_xy": sum_xy
    }
}

# %%
# todo: assign proper values
product_sum_x_sum_y = {"$multiply": ["$sum_x", "$sum_y"]}
product_sum_xy_elems = { "$multiply": ["$sum_xy", "$elems"] }
top = { "$subtract": [ product_sum_xy_elems, product_sum_x_sum_y]}

# %%
# todo: assign proper values
product_sum_x2_elems = { "$multiply": ["$sum_x2", "$elems"] }
sum_x_2 = { "$multiply": ["$sum_x", "$sum_x"] }
bottom_left = { "$subtract": [ product_sum_x2_elems, sum_x_2]}

# %%
# todo: assign proper values
product_sum_y2_elems = { "$multiply": ["$sum_y2", "$elems"] }
sum_y_2 = { "$multiply": ["$sum_y", "$sum_y"] }
bottom_right = { "$subtract": [product_sum_y2_elems, sum_y_2] }

# %%
# given -- do not change
bottom = { "$sqrt": { "$multiply": [bottom_left, bottom_right] } }
correlation = { 
    "$project": {
        "m": { "$divide": [top, bottom] }
    }
}

# %%
# given -- do not change
pipeline = [
    match_stage,
    all_sums,
    correlation
]

# %%
# given -- do not change
result = list(weather.aggregate(pipeline))
print(f"""
m = {round(result[0]['m'], 4)} (from MongoDB)
""")
# Out:
# m = 0.1069 (from MongoDB)

# %% [markdown]
# ## Compare speed to scipy
#
# Do not edit the cell below.

# %%
def in_mongo():
    result = list(weather.aggregate(pipeline))
    m = round(result[0]['m'], 4)
    return m

def using_scipy():
    pipeline = [
        {
            "$match": {
                "airTemperature.value": { "$gte": -100, "$lte": 100 },
                "pressure.value": { "$lt": 9000},
                "$comment": "nathan's run"
            }
        },
        {
            "$project": {
                "_id": 0,
                "temperature": "$airTemperature.value",
                "pressure": "$pressure.value"
            }
        }
    ]
    df = pd.DataFrame.from_dict(list(weather.aggregate(pipeline)))
    r = pearsonr(df['temperature'], df['pressure'])
    return round(r[0], 4)

# %%
print(using_scipy(), "(from scipy)")
# Out:
# 0.1069 (from scipy)

# %% [markdown]
# ## Time Difference
#
# A few reasons contribute to the massive time difference in execution.
#
# * The amount of data being transferred back is much different
# * Within MongoDB, there is no overhead of calling another library to calculate the result

# %% [markdown]
# ## Lab Answer
#
# Copy the number below after **Answer is** for the solution to the lab.

# %%
explain = db.command('aggregate', 'data', pipeline=pipeline, explain=True)
wp = zlib.adler32(json.dumps(explain['stages'][0]['$cursor']['queryPlanner']['winningPlan']).encode())


print(f"""
    Answer is {wp}
""")
# Out:
#     Answer is 3559163345

# %%
# uncomment the below line and the next cell's %timeit to compare the execution speed difference
# %timeit -n 4 in_mongo()
# Out:
# 1.35 s ± 65.1 ms per loop (mean ± std. dev. of 7 runs, 4 loops each)

# %%
# NOTE: this may be slow depending on your network and computer. 
# %timeit -n 4 using_scipy()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-20-3ea039e28114> in <module>
#       1 # NOTE: this may be slow depending on your network and computer.
# ----> 2 get_ipython().run_line_magic('timeit', '-n 4 using_scipy()')
#
# /opt/anaconda3/envs/aggregation-framework/lib/python3.6/site-packages/IPython/core/interactiveshell.py in run_line_magic(self, magic_name, line, _stack_depth)
#    2324                 kwargs['local_ns'] = sys._getframe(stack_depth).f_locals
#    2325             with self.builtin_trap:
# -> 2326                 result = fn(*args, **kwargs)
#    2327             return result
#    2328
#
# <decorator-gen-60> in timeit(self, line, cell, local_ns)
#
# /opt/anaconda3/envs/aggregation-framework/lib/python3.6/site-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# /opt/anaconda3/envs/aggregation-framework/lib/python3.6/site-packages/IPython/core/magics/execution.py in timeit(self, line, cell, local_ns)
#    1165                     break
#    1166
# -> 1167         all_runs = timer.repeat(repeat, number)
#    1168         best = min(all_runs) / number
#    1169         worst = max(all_runs) / number
#
# /opt/anaconda3/envs/aggregation-framework/lib/python3.6/timeit.py in repeat(self, repeat, number)
#     204         r = []
#     205         for i in range(repeat):
# --> 206             t = self.timeit(number)
#     207             r.append(t)
#     208         return r
#
# /opt/anaconda3/envs/aggregation-framework/lib/python3.6/site-packages/IPython/core/magics/execution.py in timeit(self, number)
#     167         gc.disable()
#     168         try:
# --> 169             timing = self.inner(it, self.timer)
#     170         finally:
#     171             if gcold:
#
# <magic-timeit> in inner(_it, _timer)
#
# <ipython-input-17-9e382068be4d> in using_scipy()
#      21         }
#      22     ]
# ---> 23     df = pd.DataFrame.from_dict(list(weather.aggregate(pipeline)))
#      24     r = pearsonr(df['temperature'], df['pressure'])
#      25     return round(r[0], 4)
#
# /opt/anaconda3/envs/aggregation-framework/lib/python3.6/site-packages/pymongo/command_cursor.py in next(self)
#     257         # Block until a document is returnable.
#     258         while self.alive:
# --> 259             doc = self._try_next(True)
#     260             if doc is not None:
#     261                 return doc
#
# /opt/anaconda3/envs/aggregation-framework/lib/python3.6/site-packages/pymongo/command_cursor.py in _try_next(self, get_more_allowed)
#     268         """Advance the cursor blocking for at most one getMore command."""
#     269         if not len(self.__data) and not self.__killed and get_more_allowed:
# --> 270             self._refresh()
#     271         if len(self.__data):
#     272             coll = self.__collection
#
# /opt/anaconda3/envs/aggregation-framework/lib/python3.6/site-packages/pymongo/command_cursor.py in _refresh(self)
#     204                                     self.__collection.database.client,
#     205                                     self.__max_await_time_ms,
# --> 206                                     False))
#     207         else:  # Cursor id is zero nothing else to return
#     208             self.__killed = True
#
# /opt/anaconda3/envs/aggregation-framework/lib/python3.6/site-packages/pymongo/command_cursor.py in __send_message(self, operation)
#     138         try:
#     139             response = client._run_operation_with_response(
# --> 140                 operation, self._unpack_response, address=self.__address)
#     141         except OperationFailure:
#     142             kill()
#
# /opt/anaconda3/envs/aggregation-framework/lib/python3.6/site-packages/pymongo/mongo_client.py in _run_operation_with_response(self, operation, unpack_res, exhaust, address)
#    1345             address=address,
#    1346             retryable=isinstance(operation, message._Query),
# -> 1347             exhaust=exhaust)
#    1348
#    1349     def _retry_with_session(self, retryable, func, session, bulk):
#
# /opt/anaconda3/envs/aggregation-framework/lib/python3.6/site-packages/pymongo/mongo_client.py in _retryable_read(self, func, read_pref, session, address, retryable, exhaust)
#    1463                         # not support retryable reads, raise the last error.
#    1464                         raise last_error
# -> 1465                     return func(session, server, sock_info, slave_ok)
#    1466             except ServerSelectionTimeoutError:
#    1467                 if retrying:
#
# /opt/anaconda3/envs/aggregation-framework/lib/python3.6/site-packages/pymongo/mongo_client.py in _cmd(session, server, sock_info, slave_ok)
#    1339                 self._event_listeners,
#    1340                 exhaust,
# -> 1341                 unpack_res)
#    1342
#    1343         return self._retryable_read(
#
# /opt/anaconda3/envs/aggregation-framework/lib/python3.6/site-packages/pymongo/server.py in run_operation_with_response(self, sock_info, operation, set_slave_okay, listeners, exhaust, unpack_res)
#     115             if send_message:
#     116                 sock_info.send_message(data, max_doc_size)
# --> 117                 reply = sock_info.receive_message(request_id)
#     118             else:
#     119                 reply = sock_info.receive_message(None)
#
# /opt/anaconda3/envs/aggregation-framework/lib/python3.6/site-packages/pymongo/pool.py in receive_message(self, request_id)
#     644                                    self.max_message_size)
#     645         except BaseException as error:
# --> 646             self._raise_connection_failure(error)
#     647
#     648     def _raise_if_not_writable(self, unacknowledged):
#
# /opt/anaconda3/envs/aggregation-framework/lib/python3.6/site-packages/pymongo/pool.py in receive_message(self, request_id)
#     642         try:
#     643             return receive_message(self.sock, request_id,
# --> 644                                    self.max_message_size)
#     645         except BaseException as error:
#     646             self._raise_connection_failure(error)
#
# /opt/anaconda3/envs/aggregation-framework/lib/python3.6/site-packages/pymongo/network.py in receive_message(sock, request_id, max_message_size)
#     212             _receive_data_on_socket(sock, length - 25), compressor_id)
#     213     else:
# --> 214         data = _receive_data_on_socket(sock, length - 16)
#     215
#     216     try:
#
# /opt/anaconda3/envs/aggregation-framework/lib/python3.6/site-packages/pymongo/network.py in _receive_data_on_socket(sock, length)
#     253         while bytes_read < length:
#     254             try:
# --> 255                 chunk_length = sock.recv_into(mv[bytes_read:])
#     256             except (IOError, OSError) as exc:
#     257                 if _errno_from_exception(exc) == errno.EINTR:
#
# /opt/anaconda3/envs/aggregation-framework/lib/python3.6/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1010                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1011                   self.__class__)
# -> 1012             return self.read(nbytes, buffer)
#    1013         else:
#    1014             return socket.recv_into(self, buffer, nbytes, flags)
#
# /opt/anaconda3/envs/aggregation-framework/lib/python3.6/ssl.py in read(self, len, buffer)
#     872             raise ValueError("Read on closed or unwrapped SSL socket.")
#     873         try:
# --> 874             return self._sslobj.read(len, buffer)
#     875         except SSLError as x:
#     876             if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# /opt/anaconda3/envs/aggregation-framework/lib/python3.6/ssl.py in read(self, len, buffer)
#     629         """
#     630         if buffer is not None:
# --> 631             v = self._sslobj.read(len, buffer)
#     632         else:
#     633             v = self._sslobj.read(len)
#
# KeyboardInterrupt:
