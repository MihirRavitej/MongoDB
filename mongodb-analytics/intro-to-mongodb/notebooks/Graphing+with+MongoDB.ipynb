# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
a = [1, 2, 3, 4, 5]
b = [x ** 2 for x in a]

# %%
print(a, b)
# Out:
# [1, 2, 3, 4, 5] [1, 4, 9, 16, 25]

# %%
plt.clf()

fig, ax = plt.subplots()

ax.scatter(a, b)

plt.show()

# %%
import pymongo
import pprint

# %%
# Replace XXXX with your connection URI from the Atlas UI
course_cluster_uri = 'mongodb://analytics-student:analytics-password@cluster0-shard-00-00-jxeqq.mongodb.net:27017,cluster0-shard-00-01-jxeqq.mongodb.net:27017,cluster0-shard-00-02-jxeqq.mongodb.net:27017/?ssl=true&replicaSet=Cluster0-shard-0&authSource=admin&ssl_cert_reqs=CERT_NONE'

# %%
course_client = pymongo.MongoClient(course_cluster_uri)
movies = course_client['mflix']['movies']

# %%
query = {
  "runtime": { "$exists": True },
  "metacritic": { "$exists": True }     
}

projection = {
  "_id": 0,
  "runtime": 1,
  "metacritic": 1
}

# %%
rm = list(movies.find(query, projection))

# %%
pprint.pprint(rm[0])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-17-26ee191bfe9a> in <module>
# ----> 1 pprint.pprint(rm[0])
#
# IndexError: list index out of range

# %%
runtimes = [movie['runtime'] for movie in rm]

# %%
print(runtimes)
# Out:
# [153, 92, 124, 100, 87, 94, 102, 102, 118, 93, 106, 102, 95, 107, 111, 97, 102, 85, 89, 80, 118, 83, 97, 104, 96, 108, 113, 207, 98, 122, 92, 172, 96, 91, 90, 103, 100, 88, 174, 88, 180, 115, 90, 84, 216, 105, 126, 90, 98, 95, 187, 116, 95, 148, 87, 125, 91, 113, 121, 137, 123, 105, 95, 161, 103, 111, 168, 106, 134, 130, 105, 160, 151, 88, 145, 110, 175, 95, 112, 140, 111, 91, 112, 139, 99, 116, 172, 90, 86, 95, 136, 104, 138, 114, 98, 80, 124, 102, 175, 167, 94, 95, 122, 80, 112, 130, 89, 129, 103, 212, 130, 113, 200, 144, 112, 91, 104, 83, 81, 124, 133, 83, 119, 100, 103, 139, 113, 124, 102, 137, 240, 105, 83, 106, 118, 100, 121, 94, 183, 110, 110, 91, 117, 109, 143, 117, 153, 118, 121, 105, 94, 88, 96, 95, 120, 83, 132, 108, 113, 124, 111, 95, 124, 114, 129, 103, 146, 103, 111, 127, 96, 97, 113, 149, 129, 110, 92, 94, 80, 129, 155, 115, 102, 122, 96, 127, 118, 117, 116, 110, 115, 85, 90, 188, 93, 124, 107, 114, 94, 150, 113, 116, 91, 103, 105, 94, 103, 110, 141, 95, 96, 100, 93, 98, 91, 107, 134, 99, 94, 170, 131, 93, 125, 132, 116, 101, 88, 105, 87, 115, 90, 128, 160, 105, 99, 122, 105, 118, 91, 96, 111, 92, 90, 93, 105, 88, 115, 107, 82, 102, 97, 116, 132, 97, 113, 94, 83, 109, 114, 120, 107, 91, 82, 162, 113, 280, 133, 91, 94, 112, 136, 137, 120, 93, 103, 103, 96, 103, 111, 116, 114, 101, 94, 119, 105, 117, 117, 118, 96, 117, 114, 119, 83, 110, 100, 102, 133, 100, 106, 153, 84, 119, 116, 110, 128, 107, 163, 110, 97, 140, 102, 107, 102, 98, 94, 102, 96, 95, 97, 134, 85, 95, 119, 126, 118, 121, 124, 91, 92, 104, 161, 108, 111, 104, 120, 116, 119, 91, 116, 110, 131, 
plt.title("Metacritic Movie Ratings vs. Movie Runtime")
plt.xlabel('Movie Runtime (minutes)')
plt.ylabel('Movie Rating (metacritic)')

plt.show()

# %%
query = {
  "runtime": { "$exists": True },
  "metacritic": { "$exists": True },
  "year": { "$exists": True }
}

projection = {
  "_id": 0,
  "runtime": 1,
  "metacritic": 1,
  "year": 1
}

# %%
rmy = list(movies.find(query, projection))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-ca7ba2f2f038> in <module>
# ----> 1 rmy = list(movies.find(query, projection))
#
# NameError: name 'movies' is not defined

# %%
runtimes = [movie['runtime'] for movie in rmy]
metacritic_ratings = [movie['metacritic'] for movie in rmy]
years = [movie['year'] for movie in rmy]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-e9cc7f1d29f5> in <module>
# ----> 1 runtimes = [movie['runtime'] for movie in rmy]
#       2 metacritic_ratings = [movie['metacritic'] for movie in rmy]
#       3 years = [movie['year'] for movie in rmy]
#
# NameError: name 'rmy' is not defined

# %%
plt.clf()

fig = plt.figure()

ax = fig.add_subplot(111, projection='3d')

ax.scatter(runtimes, metacritic_ratings, years)

plt.title('Movie Ratings vs. Runtime vs. Year')
ax.set_xlabel('Movie Runtime (minutes)')
ax.set_ylabel('Movie Rating (metacritic)')
ax.set_zlabel('Movie Year')

plt.show()
# Out:
# /Users/mpamaraj/.local/share/virtualenvs/mongo_tests-QIrqaQtM/lib/python3.7/site-packages/ipykernel_launcher.py:5: MatplotlibDeprecationWarning: Passing non-integers as three-element position specification is deprecated since 3.3 and will be removed two minor releases later.
#   """
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-fe370cb608fb> in <module>
#       5 ax = fig.add_subplot('111', projection='3d')
#       6
# ----> 7 ax.scatter(runtimes, metacritic_ratings, years)
#       8
#       9 plt.title('Movie Ratings vs. Runtime vs. Year')
#
# ~/.local/share/virtualenvs/mongo_tests-QIrqaQtM/lib/python3.7/site-packages/mpl_toolkits/mplot3d/axes3d.py in scatter(self, xs, ys, zs, zdir, s, c, depthshade, *args, **kwargs)
#    2317             self.set_zmargin(0.05)
#    2318
# -> 2319         self.auto_scale_xyz(xs, ys, zs, had_data)
#    2320
#    2321         return patches
#
# ~/.local/share/virtualenvs/mongo_tests-QIrqaQtM/lib/python3.7/site-packages/mpl_toolkits/mplot3d/axes3d.py in auto_scale_xyz(self, X, Y, Z, had_data)
#     652             Z = np.reshape(Z, -1)
#     653             self.zz_dataLim.update_from_data_xy(
# --> 654                 np.column_stack([Z, Z]), not had_data)
#     655         # Let autoscale_view figure out how to use this data.
#     656         self.autoscale_view()
#
# ~/.local/share/virtualenvs/mongo_tests-QIrqaQtM/lib/python3.7/site-packages/matplotlib/transforms.py in update_from_data_xy(self, xy, ignore, updatex, updatey)
#     905             return
#     906
# --> 907         path = Path(xy)
#     908         self.update_from_path(path, ignore=ignore,
#     909                               updatex=updatex, updatey=updatey)
#
# ~/.local/share/virtualenvs/mongo_tests-QIrqaQtM/lib/python3.7/site-packages/matplotlib/path.py in __init__(self, vertices, codes, _interpolation_steps, closed, readonly)
#     129             and codes as read-only arrays.
#     130         """
# --> 131         vertices = _to_unmasked_float_array(vertices)
#     132         cbook._check_shape((None, 2), vertices=vertices)
#     133
#
# ~/.local/share/virtualenvs/mongo_tests-QIrqaQtM/lib/python3.7/site-packages/matplotlib/cbook/__init__.py in _to_unmasked_float_array(x)
#    1287         return np.ma.asarray(x, float).filled(np.nan)
#    1288     else:
# -> 1289         return np.asarray(x, float)
#    1290
#    1291
#
# ~/.local/share/virtualenvs/mongo_tests-QIrqaQtM/lib/python3.7/site-packages/numpy/core/_asarray.py in asarray(a, dtype, order)
#      81
#      82     """
# ---> 83     return array(a, dtype, copy=False, order=order)
#      84
#      85
#
# ValueError: could not convert string to float: '2012�'
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/.local/share/virtualenvs/mongo_tests-QIrqaQtM/lib/python3.7/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# ~/.local/share/virtualenvs/mongo_tests-QIrqaQtM/lib/python3.7/site-packages/IPython/core/pylabtools.py in <lambda>(fig)
#     246
#     247     if 'png' in formats:
# --> 248         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     249     if 'retina' in formats or 'png2x' in formats:
#     250         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# ~/.local/share/virtualenvs/mongo_tests-QIrqaQtM/lib/python3.7/site-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     130         FigureCanvasBase(fig)
#     131
# --> 132     fig.canvas.print_figure(bytes_io, **kw)
#     133     data = bytes_io.getvalue()
#     134     if fmt == 'svg':
#
# ~/.local/share/virtualenvs/mongo_tests-QIrqaQtM/lib/python3.7/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2191                            else suppress())
#    2192                     with ctx:
# -> 2193                         self.figure.draw(renderer)
#    2194
#    2195                     bbox_inches = self.figure.get_tightbbox(
#
# ~/.local/share/virtualenvs/mongo_tests-QIrqaQtM/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      39                 renderer.start_filter()
#      40
# ---> 41             return draw(artist, renderer, *args, **kwargs)
#      42         finally:
#      43             if artist.get_agg_filter() is not None:
#
# ~/.local/share/virtualenvs/mongo_tests-QIrqaQtM/lib/python3.7/site-packages/matplotlib/figure.py in draw(self, renderer)
#    1862             self.patch.draw(renderer)
#    1863             mimage._draw_list_compositing_images(
# -> 1864                 renderer, self, artists, self.suppressComposite)
#    1865
#    1866             renderer.close_group('figure')
#
# ~/.local/share/virtualenvs/mongo_tests-QIrqaQtM/lib/python3.7/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130     if not_composite or not has_images:
#     131         for a in artists:
# --> 132             a.draw(renderer)
#     133     else:
#     134         # Composite any adjacent images together
#
# ~/.local/share/virtualenvs/mongo_tests-QIrqaQtM/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      39                 renderer.start_filter()
#      40
# ---> 41             return draw(artist, renderer, *args, **kwargs)
#      42         finally:
#      43             if artist.get_agg_filter() is not None:
#
# ~/.local/share/virtualenvs/mongo_tests-QIrqaQtM/lib/python3.7/site-packages/mpl_toolkits/mplot3d/axes3d.py in draw(self, renderer)
#     445                 sorted(self.collections,
#     446                        key=lambda col: col.do_3d_projection(renderer),
# --> 447                        reverse=True)):
#     448             col.zorder = zorder_offset + i
#     449         for i, patch in enumerate(
#
# ~/.local/share/virtualenvs/mongo_tests-QIrqaQtM/lib/python3.7/site-packages/mpl_toolkits/mplot3d/axes3d.py in <lambda>(col)
#     444         for i, col in enumerate(
#     445                 sorted(self.collections,
# --> 446                        key=lambda col: col.do_3d_projection(renderer),
#     447                        reverse=True)):
#     448             col.zorder = zorder_offset + i
#
# ~/.local/share/virtualenvs/mongo_tests-QIrqaQtM/lib/python3.7/site-packages/mpl_toolkits/mplot3d/art3d.py in do_3d_projection(self, renderer)
#     486     def do_3d_projection(self, renderer):
#     487         xs, ys, zs = self._offsets3d
# --> 488         vxs, vys, vzs, vis = proj3d.proj_transform_clip(xs, ys, zs, renderer.M)
#     489
#     490         fcs = (_zalpha(self._facecolor3d, vzs) if self._depthshade else
#
# ~/.local/share/virtualenvs/mongo_tests-QIrqaQtM/lib/python3.7/site-packages/mpl_toolkits/mplot3d/proj3d.py in proj_transform_clip(xs, ys, zs, M)
#     155     """
#     156     vec = _vec_pad_ones(xs, ys, zs)
# --> 157     return _proj_transform_vec_clip(vec, M)
#     158
#     159
#
# ~/.local/share/virtualenvs/mongo_tests-QIrqaQtM/lib/python3.7/site-packages/mpl_toolkits/mplot3d/proj3d.py in _proj_transform_vec_clip(vec, M)
#     112
#     113 def _proj_transform_vec_clip(vec, M):
# --> 114     vecw = np.dot(M, vec)
#     115     w = vecw[3]
#     116     # clip here.
#
# <__array_function__ internals> in dot(*args, **kwargs)
#
# TypeError: Cannot cast array data from dtype('float64') to dtype('<U32') according to the rule 'safe'

# %%
client = pymongo.MongoClient("mongodb://buildapp-student:buildapp-password@cluster0-shard-00-00-jxeqq.mongodb.net:27017,cluster0-shard-00-01-jxeqq.mongodb.net:27017,cluster0-shard-00-02-jxeqq.mongodb.net:27017/?ssl=true&replicaSet=Cluster0-shard-0&authSource=admin")
pings = client['mflix']['watching_pings']

# %%
cursor = pings.aggregate([
  {
    "$sample": { "size": 50000 }
  },
  {
    "$addFields": { 
      "dayOfWeek": { "$dayOfWeek": "$ts" },
      "hourOfDay": { "$hour": "$ts" }
    }
  },
  {
    "$group": { "_id": "$dayOfWeek", "pings": { "$push": "$$ROOT" } }
  },
  {
    "$sort": { "_id": 1 }
  }
]);
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-dff305438037> in <module>
# ----> 1 cursor = pings.aggregate([
#       2   {
#       3     "$sample": { "size": 50000 }
#       4   },
#       5   {
#
# NameError: name 'pings' is not defined

# %%
pings_by_day = [doc['pings'] for doc in cursor]

# %%
pings_by_hour_by_day = [[ping['hourOfDay'] for ping in pings] for pings in pings_by_day]

# %%
plt.clf()

fig, ax = plt.subplots()

ax.boxplot(pings_by_hour_by_day)

ax.set_title('January 2016 Trip Duration by Day')
ax.yaxis.grid(True)
ax.set_xticklabels(['Sun', 'Mon', 'Tues', 'Wed', 'Thur', 'Fri', 'Sat'])
ax.set_xlabel('Days of Week')
ax.set_ylabel('Trip Duration (minutes)')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-69af0a577228> in <module>
#       3 fig, ax = plt.subplots()
#       4
# ----> 5 ax.boxplot(pings_by_hour_by_day)
#       6
#       7 ax.set_title('January 2016 Trip Duration by Day')
#
# NameError: name 'pings_by_hour_by_day' is not defined
